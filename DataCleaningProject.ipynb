# %% [markdown]
# <a href="https://colab.research.google.com/github/krGaurav310/AllColabProjects/blob/master/DataCleaningProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-72d1a2f0-26c7-41e4-b6d0-85d1a27defef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-72d1a2f0-26c7-41e4-b6d0-85d1a27defef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"kumargaurav310","key":"ec76d65ed7c779b52f6de1d6bdb07e7f"}'}

# %%
# !mkdir -p ~/.kaggle #code to manage folders and all
# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d maxhorowitz/nflplaybyplay2009to2016
# Out:
# ...
#  97% 265M/274M [00:02<00:00, 134MB/s]
# 100% 274M/274M [00:02<00:00, 114MB/s]

# %%
#!kaggle datasets download -d kaggle datasets download -d maxhorowitz/nflplaybyplay2009to2016

# %%
from zipfile import ZipFile

# %%
#from zipfile import ZipFile
file_name = "nflplaybyplay2009to2016.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print("Done")
# Out:
# Done

# %%
import pandas as pd

# %%
nfl_data  = pd.read_csv("/content/NFL Play by Play 2009-2017 (v4).csv")
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (25,51) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
nfl_data.columns
# Out:
# Index(['Date', 'GameID', 'Drive', 'qtr', 'down', 'time', 'TimeUnder',
#        'TimeSecs', 'PlayTimeDiff', 'SideofField',
#        ...
#        'yacEPA', 'Home_WP_pre', 'Away_WP_pre', 'Home_WP_post', 'Away_WP_post',
#        'Win_Prob', 'WPA', 'airWPA', 'yacWPA', 'Season'],
#       dtype='object', length=102)

# %%
#mdata = pd.read_csv("metadata.csv")

# %%
#mdata.info()

# %%
nfl_data.head(5)
# Out:
#          Date      GameID  Drive  qtr  ...       WPA    airWPA    yacWPA  Season
# 0  2009-09-10  2009091000      1    1  ...  0.060758       NaN       NaN    2009
# 1  2009-09-10  2009091000      1    1  ...  0.004655 -0.032244  0.036899    2009
# 2  2009-09-10  2009091000      1    1  ... -0.040295       NaN       NaN    2009
# 3  2009-09-10  2009091000      1    1  ... -0.049576  0.106663 -0.156239    2009
# 4  2009-09-10  2009091000      1    1  ...  0.097712       NaN       NaN    2009
#
# [5 rows x 102 columns]

# %%
missing_values_count = nfl_data.isnull().sum()

# %%
missing_values_count
# Out:
# Date             0
# GameID           0
# Drive            0
# qtr              0
# down         61154
#              ...
# Win_Prob     25009
# WPA           5541
# airWPA      248501
# yacWPA      248762
# Season           0
# Length: 102, dtype: int64

# %%
missing_values_count[0:10]
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            61154
# time              224
# TimeUnder           0
# TimeSecs          224
# PlayTimeDiff      444
# SideofField       528
# dtype: int64

# %%
import numpy as np

# %%
total_cells = np.product(nfl_data.shape)

# %%
total_missing = missing_values_count.sum()

# %%
(total_missing/total_cells) * 100
# Out:
# 24.87214126835169

# %%
nfl_data.dropna()
# Out:
# Empty DataFrame
# ...

# %%
# remove all columns with at least one missing value
columns_with_na_dropped = nfl_data.dropna(axis = 1)

# %%
columns_with_na_dropped.head()
# Out:
#          Date      GameID  Drive  ...  ExPoint_Prob  TwoPoint_Prob  Season
# 0  2009-09-10  2009091000      1  ...           0.0            0.0    2009
# 1  2009-09-10  2009091000      1  ...           0.0            0.0    2009
# 2  2009-09-10  2009091000      1  ...           0.0            0.0    2009
# 3  2009-09-10  2009091000      1  ...           0.0            0.0    2009
# 4  2009-09-10  2009091000      1  ...           0.0            0.0    2009
#
# [5 rows x 41 columns]

# %%
# just how much data did we lose?
print("Columns in original dataset: %d \n" % nfl_data.shape[1])
print("Columns with na's dropped: %d" % columns_with_na_dropped.shape[1])
# Out:
# Columns in original dataset: 102
#
# Columns with na's dropped: 41

# %%
# get a small subset of the NFL dataset
subset_nfl_data = nfl_data.loc[:, 'EPA':'Season'].head()
subset_nfl_data
# Out:
#         EPA    airEPA    yacEPA  ...    airWPA    yacWPA  Season
# 0  2.014474       NaN       NaN  ...       NaN       NaN    2009
# 1  0.077907 -1.068169  1.146076  ... -0.032244  0.036899    2009
# 2 -1.402760       NaN       NaN  ...       NaN       NaN    2009
# 3 -1.712583  3.318841 -5.031425  ...  0.106663 -0.156239    2009
# 4  2.097796       NaN       NaN  ...       NaN       NaN    2009
#
# [5 rows x 12 columns]

# %%
subset_nfl_data1 = nfl_data.iloc[:,:12].head()
subset_nfl_data1
# Out:
#          Date      GameID  Drive  ...  SideofField  yrdln yrdline100
# 0  2009-09-10  2009091000      1  ...          TEN   30.0       30.0
# 1  2009-09-10  2009091000      1  ...          PIT   42.0       58.0
# 2  2009-09-10  2009091000      1  ...          PIT   47.0       53.0
# 3  2009-09-10  2009091000      1  ...          PIT   44.0       56.0
# 4  2009-09-10  2009091000      1  ...          PIT   44.0       56.0
#
# [5 rows x 12 columns]

# %%
subset_nfl_data
# Out:
#         EPA    airEPA    yacEPA  ...    airWPA    yacWPA  Season
# 0  2.014474       NaN       NaN  ...       NaN       NaN    2009
# 1  0.077907 -1.068169  1.146076  ... -0.032244  0.036899    2009
# 2 -1.402760       NaN       NaN  ...       NaN       NaN    2009
# 3 -1.712583  3.318841 -5.031425  ...  0.106663 -0.156239    2009
# 4  2.097796       NaN       NaN  ...       NaN       NaN    2009
#
# [5 rows x 12 columns]

# %%
subset_nfl_data.fillna(method = 'bfill', axis=0).fillna(0).head(10)
# Out:
#         EPA    airEPA    yacEPA  ...    airWPA    yacWPA  Season
# 0  2.014474 -1.068169  1.146076  ... -0.032244  0.036899    2009
# 1  0.077907 -1.068169  1.146076  ... -0.032244  0.036899    2009
# 2 -1.402760  3.318841 -5.031425  ...  0.106663 -0.156239    2009
# 3 -1.712583  3.318841 -5.031425  ...  0.106663 -0.156239    2009
# 4  2.097796  0.000000  0.000000  ...  0.000000  0.000000    2009
#
# [5 rows x 12 columns]
